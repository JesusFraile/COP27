# %%
import pandas as pd

# %%
df=pd.read_pickle('/data/jfraile/Programs/COP27/datasets_with_answer/objectives_cop_no_guide_cop27_en_original_full_text_batch_20.pkl')

# %%
df
# Out:
#                           id  \
# 1        1592185555768561664
# 13       1592185506552774657
# 19       1592185481865093122
# 21       1592185465243062273
# 23       1592185456744988672
# ...                      ...
# 1513153  1590370622013845504
# 1513172  1590370574378754049
# 1513179  1590370558298165249
# 1513189  1590370519257579520
# 1513191  1590370517336616961
#
#                                                       Text objectives
# 1        As we continue to the discussion on the nexus ...        [1]
# 13       🔴At #COP27, we:\n➡️Plan to pioneer financing f...     [2, 6]
# 19       While excited for #COP27 and working to solve ...        [7]
# 21       Science has created the climate crisis, scienc...     [1, 6]
# 23       Talking about #LossAndDamage at #COP27 is over...        [6]
# ...                                                    ...        ...
# 1513153  Join me and @devex as we dig into cross-cuttin...        NaN
# ...
